# %% [markdown]
# ### Imports

# %%
import googlemaps
import pandas as pd
import pprint
import time

# %%
API_key = open('API_KEY.txt','r').read()
gmaps = googlemaps.Client(key=API_key)

# %%
places_result = gmaps.places_nearby(location="23.684994,90.356331",radius=30000,type="restaurant")

# %%
pprint.pprint(places_result)
# Out:
# {'html_attributions': [],
#  'next_page_token': 'Aap_uED1XqUQrr9EbGWTokStBASslKQdU206sr_Ir-a4pWKEV0DDU5I52hFDEoQ_7kVi9ul2PxtsS0wWIv_4XT44wc7QbpqeypsCrQ6K1ioenWuCJOZo8eWuhahJzzrI8vJ6cUgKjeMJdKnpuOAKuP34hkl-rGjwS8gLXeVpNkHrPMMYDe6dTwoOJtQGgx8pvAzXSRY4M8Sstnesyu-U5lIAxm_zVxB22iDJPPkt6rhiNh6VSYuJj31k33nHqJoE_peOZwPxoTmQfOMGt_-3acqyo75JaPHER9ELDy95gZEBkjXmDGIrmYFgQAsx01-KnrWvw2Qn48hLkSHum3iPo08XXTWfRsaamNFY57FDf6MwDvrbq_K8dL7Ngv_Bwif0GHWLt3zPYIUi7q7TlenVBEI63z4fHoobqUQBJ_Wu-8hC1E_I-nVyLlk2RQRcTMcc',
#  'results': [{'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.8293473, 'lng': 90.4194605},
#                            'viewport': {'northeast': {'lat': 23.8307055802915,
#                                                       'lng': 90.42088898029151},
#                                         'southwest': {'lat': 23.8280076197085,
#                                                       'lng': 90.41819101970849}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Dhaka Regency Hotel & Resort',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 460,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/102988157688212246157">Dhaka '
#                                                 'Regency Hotel &amp; '
#                                                 'Resort</a>'],
#                           'photo_reference': 'Aap_uEBvjepdgTmv4k6nN4oxmY0PTdOoagC5njHlFwJ10J9nASLBVOk3O5n52TzwaTiOlsz9POkWxBtKisY9kQeP8Qc_eTewkFwhEMS6-pgyegCXuWhNPCwEL_fj1f8WUTKQKscvdjWbcM35gF9NLZy3cGwbXRlKjSKtHGgr10e2hwcqpf32',
#                           'width': 817}],
#               'place_id': 'ChIJCw5dYFzGVTcRX0HsF-ByEuk',
#               'plus_code': {'compound_code': 'RCH9+PQ Dhaka, Bangladesh',
#                             'global_code': '7MMGRCH9+PQ'},
#               'rating': 4.3,
#               'reference': 'ChIJCw5dYFzGVTcRX0HsF-ByEuk',
#               'scope': 'GOOGLE',
#               'types': ['spa',
#                         'lodging',
#                         'bar',
#                         'restaurant',
#                         'food',
#                         'gym',
#                         'health',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 5985,
#               'vicinity': 'Airport Rd, Dhaka'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.7317486, 'lng': 90.4098029},
#                            'viewport': {'northeast': {'lat': 23.7330617302915,
#                                                       'lng': 90.41124398029152},
#                                         'southwest': {'lat': 23.7303637697085,
#                                                       'lng': 90.4085460197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'FARS Hotel & Resorts',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1824,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/110713737147016591291">FARS '
#                                                 'Hotel &amp; Resorts</a>'],
#                           'photo_reference': 'Aap_uEAcyxLvE6CLczSFL5cjmG9gdQwImX0_AzJcQe-IFta8f-nlL8AuwCNUWOxywPXuhAQaAdP0oomnRoCRLErbOvJ_DUMEJNqhvZ2J85aFugK2mDng2isqasMhYDjeeiRrMvFLM-frk-KOeKlkAdasgciQ_LIaw-MzpGogcC_zISCGh6ub',
#                           'width': 2736}],
#               'place_id': 'ChIJK3CIi_a4VTcRQ_C-Q7Hi6q0',
#               'plus_code': {'compound_code': 'PCJ5+MW Dhaka, Bangladesh',
#                             'global_code': '7MMGPCJ5+MW'},
#               'rating': 4.2,
#               'reference': 'ChIJK3CIi_a4VTcRQ_C-Q7Hi6q0',
#               'scope': 'GOOGLE',
#               'types': ['spa',
#                         'lodging',
#                         'restaurant',
#                         'food',
#                         'gym',
#                         'health',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 3551,
#               'vicinity': 'Akram Center, 212 Shahid Syed Nazrul Islam Sharani, '
#                           'Dhaka'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.86557569999999,
#                                         'lng': 90.40499419999999},
#                            'viewport': {'northeast': {'lat': 23.8669584302915,
#                                                       'lng': 90.4063423802915},
#                                         'southwest': {'lat': 23.86426046970849,
#                                                       'lng': 90.4036444197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Anchorage The Residence',
#               'photos': [{'height': 3456,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/113595890306237515395">Anchorage '
#                                                 'The Residence</a>'],
#                           'photo_reference': 'Aap_uEB8FDj1sq02VsgKAgoyGzhXgx5O-276EhendbXUxS5fPlXdhDZqqq_0eiHyeYvQ3RPpxa3GFuwCvZZTVFE2sTSP8YKDlEiG8ECvV4tjDRuZ6PGFfgRicyFgvcnjnJUuVKIeAdEe6ey86cYwu08J5zwUNiG2866YA8Hx2ls7wYWf2WjJ',
#                           'width': 5184}],
#               'place_id': 'ChIJdVymGC_EVTcRKvWlOp6wras',
#               'plus_code': {'compound_code': 'VC83+6X Dhaka, Bangladesh',
#                             'global_code': '7MMGVC83+6X'},
#               'rating': 4.2,
#               'reference': 'ChIJdVymGC_EVTcRKvWlOp6wras',
#               'scope': 'GOOGLE',
#               'types': ['lodging',
#                         'restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 256,
#               'vicinity': 'House No, 14 Road No.18, Dhaka'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.7932655, 'lng': 90.4043303},
#                            'viewport': {'northeast': {'lat': 23.79454938029151,
#                                                       'lng': 90.40566968029151},
#                                         'southwest': {'lat': 23.7918514197085,
#                                                       'lng': 90.4029717197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Hotel Sarina Dhaka',
#               'photos': [{'height': 927,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/102468731678954385091">Hotel '
#                                                 'Sarina Dhaka</a>'],
#                           'photo_reference': 'Aap_uED5CD3ombpaqq3CvRxBvSy743YDQkkG7lHctmses6yDJpEiV6UrsrxK8b7i9b5fZZNfjG4dkr3d4bW_eh7uzU83_o18RfT33ck7IdkZs3jr5o2i52vQxDwChFWU4dPq-fXjfvVsPTSynHynwave2np8b4JUaQzVBmi7sKhjMsrPxzs',
#                           'width': 771}],
#               'place_id': 'ChIJc-vsbw7HVTcR3MoAoofTxMc',
#               'plus_code': {'compound_code': 'QCV3+8P Dhaka, Bangladesh',
#                             'global_code': '7MMGQCV3+8P'},
#               'rating': 4.3,
#               'reference': 'ChIJc-vsbw7HVTcR3MoAoofTxMc',
#               'scope': 'GOOGLE',
#               'types': ['cafe',
#                         'lodging',
#                         'bar',
#                         'restaurant',
#                         'food',
#                         'point_of_interest',
#                         'store',
#                         'establishment'],
#               'user_ratings_total': 3007,
#               'vicinity': 'Plot #27, Road #17, Banani C/A, Dhaka'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.73506669999999,
#                                         'lng': 90.4106039},
#                            'viewport': {'northeast': {'lat': 23.7364452302915,
#                                                       'lng': 90.4118031302915},
#                                         'southwest': {'lat': 23.73374726970849,
#                                                       'lng': 90.4091051697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Hotel 71',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1367,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/109187358065745066732">Hotel '
#                                                 '71</a>'],
#                           'photo_reference': 'Aap_uED4QrtfNuYDv5mV93q4dNEoT3xo-0ZtT5RTQSdxkLo0tSmZFxH1vczXTbeb2YDqhqBcoA0DAAUvGSsbRtNYwy2uEHkL0lKPIuuVJWUQ6smB3r89k9RtKc7Ee2hOWtYtAP_qPRNYUFsyxySBE7Ipq4bEPVYA0-NOdSlBhMVjbte48ArJ',
#                           'width': 1920}],
#               'place_id': 'ChIJF6c7svW4VTcRE8smvklihXA',
#               'plus_code': {'compound_code': 'PCP6+26 Dhaka, Bangladesh',
#                             'global_code': '7MMGPCP6+26'},
#               'rating': 4,
#               'reference': 'ChIJF6c7svW4VTcRE8smvklihXA',
#               'scope': 'GOOGLE',
#               'types': ['lodging',
#                         'bar',
#                         'restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 3417,
#               'vicinity': '176, Shaheed Syed Nazrul Islam Sarani, 47 Bijoy '
#                           'Nagar Road, Dhaka'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.7937058, 'lng': 90.4044627},
#                            'viewport': {'northeast': {'lat': 23.7951662302915,
#                                                       'lng': 90.40582983029151},
#                                         'southwest': {'lat': 23.7924682697085,
#                                                       'lng': 90.40313186970849}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': 'Boomers Cafe',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 867,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/106126542592017264464">Boomers '
#                                                 'Cafe</a>'],
#                           'photo_reference': 'Aap_uECZKyX7Yu3YY0NV92c73piLanj_0O9IsQRx7iLk-PUA__MEecaV2QL6Q6Zt_jouXsXlA1k5QyL_42bDYeOxKqpDQoBA4KdMuZ0Ls1DAlURYbzbxG89XFDVYD3krCQNQv-0j2h05lIB0hN0XDZOWvrrZv7eeE3ayO987e3AWGz65q9oP',
#                           'width': 1300}],
#               'place_id': 'ChIJpbHuZg7HVTcReSeEN13tXUY',
#               'plus_code': {'compound_code': 'QCV3+FQ Dhaka, Bangladesh',
#                             'global_code': '7MMGQCV3+FQ'},
#               'price_level': 2,
#               'rating': 4.1,
#               'reference': 'ChIJpbHuZg7HVTcReSeEN13tXUY',
#               'scope': 'GOOGLE',
#               'types': ['restaurant',
#                         'cafe',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 1721,
#               'vicinity': 'A.R Tower, (2nd Floor, 24 Kemal Ataturk Avenue, '
#                           'Dhaka'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.7815354, 'lng': 90.4140889},
#                            'viewport': {'northeast': {'lat': 23.7828853302915,
#                                                       'lng': 90.41551883029149},
#                                         'southwest': {'lat': 23.7801873697085,
#                                                       'lng': 90.41282086970848}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Hotel De Crystal Crown',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 3456,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/103323300219463450988">Hotel '
#                                                 'De Crystal Crown</a>'],
#                           'photo_reference': 'Aap_uEA3BEnNXw_REVLb5Imoqdw3XGb51WE0VDAcZ-pl_1OAvYyb0M_DvoZ7Fm6kNLI5JI9M5lPM3yp6jMVB7ZMpSo_BPJuXrIPtQHQVpEAI8XHjSBv7SJdQa0gHEAKp1-rseIHxynZRMs1zHr865W_yTnFx_rtwbShdzFB2JOwbuoRA56E',
#                           'width': 5184}],
#               'place_id': 'ChIJK9RJbp7HVTcR8UcgsG1HYgQ',
#               'plus_code': {'compound_code': 'QCJ7+JJ Dhaka, Bangladesh',
#                             'global_code': '7MMGQCJ7+JJ'},
#               'rating': 3.9,
#               'reference': 'ChIJK9RJbp7HVTcR8UcgsG1HYgQ',
#               'scope': 'GOOGLE',
#               'types': ['lodging',
#                         'restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 395,
#               'vicinity': 'House # 5 Road 23/A, Dhaka'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.7808142, 'lng': 90.4168854},
#                            'viewport': {'northeast': {'lat': 23.7822176802915,
#                                                       'lng': 90.41832143029151},
#                                         'southwest': {'lat': 23.7795197197085,
#                                                       'lng': 90.41562346970849}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': 'Purnima Restaurant',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 2368,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/115029425601246152704">Zahid '
#                                                 'Rasel</a>'],
#                           'photo_reference': 'Aap_uECW8vQd8fNjgUqJAvs_-4O3fIpk-OiBIhUHUS-EtfTM3FexqeuQCV2lDu_0lhj--FEPD1ria9MCXWRUAXge9zohGgk3aaPsMQfAhbEvKNIeBNv9OkuMPRJtqRawtVGQTKvpCAIG5jIJHAXQvbMCTpHt1CoPa1TLIv8RTnczNVv_WFw2',
#                           'width': 4208}],
#               'place_id': 'ChIJoYx3qZ7HVTcRml4x1RVFg0k',
#               'plus_code': {'compound_code': 'QCJ8+8Q Dhaka, Bangladesh',
#                             'global_code': '7MMGQCJ8+8Q'},
#               'price_level': 2,
#               'rating': 3.7,
#               'reference': 'ChIJoYx3qZ7HVTcRml4x1RVFg0k',
#               'scope': 'GOOGLE',
#               'types': ['restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 1172,
#               'vicinity': '50, Habib Market, Gulshan Avenue, Gulshan 1, '
#                           'Opposite Navana Tower, Dhaka'},
#              {'business_status': 'CLOSED_TEMPORARILY',
#               'geometry': {'location': {'lat': 23.8024493,
#                                         'lng': 90.39592189999999},
#                            'viewport': {'northeast': {'lat': 23.8038542802915,
#                                                       'lng': 90.39720923029151},
#                                         'southwest': {'lat': 23.8011563197085,
#                                                       'lng': 90.39451126970849}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': 'Tasty Tibet - CSD',
#               'permanently_closed': True,
#               'photos': [{'height': 3024,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/117357097273308005946">Mohammad '
#                                                 'Ziaul Hoque</a>'],
#                           'photo_reference': 'Aap_uEDTRFGJP-vjOA4AIRv9WsLccP7QxUuBxb-_65IikPWSJl_QznuJv9nrBCE-bfmLrhuvKYCspwbS4gdj7RrlW__FhpfSlGveJAff_m5sQSh8SYteV8qZj2RN1MVhpUFRhdc_G8db_3Yz0hIoiUMiTPx8TTqpVkR7PeGGE3sLF843sCjs',
#                           'width': 4032}],
#               'place_id': 'ChIJu0w3GRnHVTcRx7hagSiVCis',
#               'plus_code': {'compound_code': 'R92W+X9 Dhaka, Bangladesh',
#                             'global_code': '7MMGR92W+X9'},
#               'price_level': 2,
#               'rating': 4.3,
#               'reference': 'ChIJu0w3GRnHVTcRx7hagSiVCis',
#               'scope': 'GOOGLE',
#               'types': ['restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 77,
#               'vicinity': 'CSD DCS TESS CSD Bhaban, Shaheed Sharani, Dhaka'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.7501048, 'lng': 90.4159516},
#                            'viewport': {'northeast': {'lat': 23.7514437802915,
#                                                       'lng': 90.4173455302915},
#                                         'southwest': {'lat': 23.7487458197085,
#                                                       'lng': 90.41464756970849}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': 'Dhaka Fried Chicken',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 3000,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/108724188344481670509">Muhammed '
#                                                 'Waliur Rahman</a>'],
#                           'photo_reference': 'Aap_uEBiuCyRWMwU_6fZMFPtJcmP9fSPlU5ZXlrkcDoMZ9jrZE7Sw-AmHfyrmgtgVejDQtiTh_tmixo9x6_ryn0EGNPdxgi1NtWMMreLvfrsad4AMVEvgxaSJFBB1zYPE4tE1MZcvQBHyPDKFDJrA4tj6Yv-2lSTEjwi-d7YGlWiQyAR94yD',
#                           'width': 4000}],
#               'place_id': 'ChIJ-TT3N2O4VTcRnzvQxyVsGd4',
#               'rating': 3.9,
#               'reference': 'ChIJ-TT3N2O4VTcRnzvQxyVsGd4',
#               'scope': 'GOOGLE',
#               'types': ['restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 139,
#               'vicinity': 'QC28+29W, Dhaka'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.7370913, 'lng': 90.389831},
#                            'viewport': {'northeast': {'lat': 23.7384072802915,
#                                                       'lng': 90.39117573029151},
#                                         'southwest': {'lat': 23.7357093197085,
#                                                       'lng': 90.38847776970849}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': 'অষ্ট ব্যঞ্জন রেস্টুরেন্ট',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 3472,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/117631769184277929240">Sagor '
#                                                 'Ahmed</a>'],
#                           'photo_reference': 'Aap_uEBjS1u29myHbaLE1lqBTMMr1c82V7zujSPC4e_PvFk569lV-ngElSjSoGho1WQ8yHO1HPr-8CWq3Cu8qS69l9nyG7MsShJQlMbe6nyUGcIYKVeUIc8ikXMEZzfwj-xk0n50B6Id1npIXoPnF4hJg2wefxS8H6f4C22yDBHQ52VNkEb9',
#                           'width': 4624}],
#               'place_id': 'ChIJeXJewcC4VTcRzPk0TeRWi1o',
#               'plus_code': {'compound_code': 'P9PQ+RW Dhaka, Bangladesh',
#                             'global_code': '7MMGP9PQ+RW'},
#               'price_level': 2,
#               'rating': 3.9,
#               'reference': 'ChIJeXJewcC4VTcRzPk0TeRWi1o',
#               'scope': 'GOOGLE',
#               'types': ['restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 1178,
#               'vicinity': '257, 8 New Elephant Road, Dhaka'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.790506,
#                                         'lng': 90.40775780000001},
#                            'viewport': {'northeast': {'lat': 23.7918005802915,
#                                                       'lng': 90.4090986802915},
#                                         'southwest': {'lat': 23.7891026197085,
#                                                       'lng': 90.4064007197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/bar_pinlet',
#               'name': 'Bluemoon Recreation Club',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 750,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/111525150632793044484">Dhaka&#39;s2ndFunniestDude</a>'],
#                           'photo_reference': 'Aap_uEDdXnKJUwtffqM2p2vjc3NhTxq7SujrRmRDyMGt3GBDC1n0xXUNjBJpB5PacBtAMNtVBrlJAuiM3txsG6fHnK7GwZ-4Rfp7Hck8-eOmtX6-z47VrDXd0JTddijR9VvClD7_6EhJbd-GsMTKmxb8LJcdFQB6XCFY2CxzE-oa0QsT-P2A',
#                           'width': 750}],
#               'place_id': 'ChIJxasydgzHVTcRILoDiDYbcyM',
#               'plus_code': {'compound_code': 'QCR5+64 Dhaka, Bangladesh',
#                             'global_code': '7MMGQCR5+64'},
#               'price_level': 2,
#               'rating': 4.2,
#               'reference': 'ChIJxasydgzHVTcRILoDiDYbcyM',
#               'scope': 'GOOGLE',
#               'types': ['bar',
#                         'restaurant',
#                         'food',
#                         'gym',
#                         'health',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 1456,
#               'vicinity': 'Plot 67/D, 3rd Floor, Green Delux Cross Point Road '
#                           '# 11,12, Block # E, Banani, Dhaka'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.8120563, 'lng': 90.4220469},
#                            'viewport': {'northeast': {'lat': 23.8133625302915,
#                                                       'lng': 90.42340033029151},
#                                         'southwest': {'lat': 23.8106645697085,
#                                                       'lng': 90.42070236970851}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': 'Magpie Thai and Chinese Restaurant',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 720,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/105974512057796278586">mgh '
#                                                 'reza</a>'],
#                           'photo_reference': 'Aap_uEAnBfUUuG1YxF4Hl6MrsCPLUyP6BABdQaWADGsDBUVbeilLeuZnpp9aeeMDKEuBqp8tp_ik8XhvOeJmc1sXWjom-bRNCEK4xqJUqKRbLag3w8RIGwuatfLQSKAlvQSR03fBFVkV-fUCL5OaHEn-1vulJRgN3WHZoXp7IXnFq2t3d5ER',
#                           'width': 1280}],
#               'place_id': 'ChIJozRxWq3HVTcRxryJMys-sFs',
#               'plus_code': {'compound_code': 'RC6C+RR Dhaka, Bangladesh',
#                             'global_code': '7MMGRC6C+RR'},
#               'price_level': 2,
#               'rating': 4,
#               'reference': 'ChIJozRxWq3HVTcRxryJMys-sFs',
#               'scope': 'GOOGLE',
#               'types': ['restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 689,
#               'vicinity': 'Bashundhara Road, Dhaka'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.7514996, 'lng': 90.3680918},
#                            'viewport': {'northeast': {'lat': 23.75279198029151,
#                                                       'lng': 90.3693473302915},
#                                         'southwest': {'lat': 23.7500940197085,
#                                                       'lng': 90.3666493697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': 'Four Seasons Restaurant',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 3840,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/100596369002226986840">Four '
#                                                 'Seasons Restaurant</a>'],
#                           'photo_reference': 'Aap_uEDGz8ke-dvZJZGMsGMV-AAOOqb5VgcbGuIg-4CbZ_js7GNY3MlwxquwJjBoVDEFAs1T7kDv6u_CLf8ZHVmcefaLXKugh8SdUrtDA8itEOPMXSYdt2XPYm9-OU2sBn2YcrV56FlbutGFtkL51xFJjbEzSzYVHD8MmpDtYvJTjIIac3gu',
#                           'width': 5760}],
#               'place_id': 'ChIJ90N_0VG_VTcRnO4r_0aCpQ4',
#               'plus_code': {'compound_code': 'Q929+H6 Dhaka, Bangladesh',
#                             'global_code': '7MMGQ929+H6'},
#               'price_level': 2,
#               'rating': 4.1,
#               'reference': 'ChIJ90N_0VG_VTcRnO4r_0aCpQ4',
#               'scope': 'GOOGLE',
#               'types': ['restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 3179,
#               'vicinity': '59/A, Satmasjid Road, Road No: 16(New) 27(Old '
#                           'Dhaka'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.7411337,
#                                         'lng': 90.41856709999999},
#                            'viewport': {'northeast': {'lat': 23.7424634802915,
#                                                       'lng': 90.41989728029151},
#                                         'southwest': {'lat': 23.7397655197085,
#                                                       'lng': 90.4171993197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Hotel Ashrafee',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 3024,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/106809683547053995312">Md. '
#                                                 'Jamiul Haider</a>'],
#                           'photo_reference': 'Aap_uEDBri1HLVqyUPJxbwhoU2bogkmKrU3WJ5pjFhBVk7UXZjAm8OwNQtM6udbDZlJLUXH8iUH56NfNxY1f74d_nzIoFBj30_y85GRdYTpp4jco98TZ8qJ2ME0_n5nZqLGmMWrsw-i8VYQ4LyK7VXjOlu5oEupmJ3gIBEs8QSlx65qiHXA',
#                           'width': 4032}],
#               'place_id': 'ChIJt5fXRGG4VTcR3MCweAU1CN8',
#               'plus_code': {'compound_code': 'PCR9+FC Dhaka, Bangladesh',
#                             'global_code': '7MMGPCR9+FC'},
#               'price_level': 2,
#               'rating': 3.9,
#               'reference': 'ChIJt5fXRGG4VTcR3MCweAU1CN8',
#               'scope': 'GOOGLE',
#               'types': ['lodging',
#                         'restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 659,
#               'vicinity': '12 Outer Circular Road, Dhaka'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.7401676, 'lng': 90.3748585},
#                            'viewport': {'northeast': {'lat': 23.7415354802915,
#                                                       'lng': 90.37625123029152},
#                                         'southwest': {'lat': 23.7388375197085,
#                                                       'lng': 90.3735532697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': 'Baburchi Restaurant',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 2368,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/115029425601246152704">Zahid '
#                                                 'Rasel</a>'],
#                           'photo_reference': 'Aap_uEC9Ev19OvANEz4SzO49DfUA23ktuzG5WK-fbbeRcgLQ_gYx1h_lo-KwvzAGneqbmH8bD6HUxYG4dgpteh-pZmNqapiitIMt4dOEtj7Woj6yGB41jPdOiQ2mzN0dAtWhh3fU5_ZlxZ6IBHFKhjRLwJaHlpW8rT7xNySP6MqWwl4oHb11',
#                           'width': 4208}],
#               'place_id': 'ChIJO7jhtEq_VTcRdP9-xL27FaU',
#               'plus_code': {'compound_code': 'P9RF+3W Dhaka, Bangladesh',
#                             'global_code': '7MMGP9RF+3W'},
#               'price_level': 2,
#               'rating': 3.6,
#               'reference': 'ChIJO7jhtEq_VTcRdP9-xL27FaU',
#               'scope': 'GOOGLE',
#               'types': ['restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 510,
#               'vicinity': 'H#55/A, Rd#4/A, Satmasjid Road, Dhaka'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.7634397,
#                                         'lng': 90.38890049999999},
#                            'viewport': {'northeast': {'lat': 23.7647860802915,
#                                                       'lng': 90.39024983029151},
#                                         'southwest': {'lat': 23.76208811970849,
#                                                       'lng': 90.38755186970849}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': 'Yummy Yummy',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 3024,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/102298133910821876116">Sharif '
#                                                 'Parvez</a>'],
#                           'photo_reference': 'Aap_uEBnXoQkXL-RvM_yDahCT0BsDHk97JR5iozJr0me8PyBuuJPpALMoLd4r1Nk18vmIn97w7KwQD-mH4Uhg972FGo8aHY9jNT0urP4SJxdSUmjps88NlzM7umxTCeNzzVTiWtAtoOi6rIdhDOrvPnJm3rNq8puzzzkAbmmr1Z4OarM-D_E',
#                           'width': 4032}],
#               'place_id': 'ChIJv4-psljHVTcRQEfCdK8-3IA',
#               'plus_code': {'compound_code': 'Q97Q+9H Dhaka, Bangladesh',
#                             'global_code': '7MMGQ97Q+9H'},
#               'rating': 3.6,
#               'reference': 'ChIJv4-psljHVTcRQEfCdK8-3IA',
#               'scope': 'GOOGLE',
#               'types': ['bakery',
#                         'restaurant',
#                         'food',
#                         'point_of_interest',
#                         'store',
#                         'establishment'],
#               'user_ratings_total': 255,
#               'vicinity': 'Old Airport Rd, Dhaka'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.7369696, 'lng': 90.4123102},
#                            'viewport': {'northeast': {'lat': 23.7382532802915,
#                                                       'lng': 90.41363553029151},
#                                         'southwest': {'lat': 23.7355553197085,
#                                                       'lng': 90.4109375697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': 'Mid Night Sun 3',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1080,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/105152252412879236970">Nowshad&#39;s '
#                                                 'Explorista</a>'],
#                           'photo_reference': 'Aap_uECbdEm-7zhJBUNdGi9a7lQW5e7veI30CPiIyMPRbWg9t4IJCUKE-fkK2O6bpK-UXqEveaW8W2MmVMqAec_JboKNOm9JlSfoxz6NWaOudRWv0YBHM6uMzH-NXeEPcU3-2JNTpwVWAyABR99qc9U21uIiP_PEDTqYnf5zPh3gHUJoOJSO',
#                           'width': 1920}],
#               'place_id': 'ChIJ3zW_Y_W4VTcRe5YltDtLaxc',
#               'plus_code': {'compound_code': 'PCP6+QW Dhaka, Bangladesh',
#                             'global_code': '7MMGPCP6+QW'},
#               'rating': 3.8,
#               'reference': 'ChIJ3zW_Y_W4VTcRe5YltDtLaxc',
#               'scope': 'GOOGLE',
#               'types': ['restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 641,
#               'vicinity': '56 VIP Road, Dhaka'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.802477, 'lng': 90.4229629},
#                            'viewport': {'northeast': {'lat': 23.8038149802915,
#                                                       'lng': 90.4242450302915},
#                                         'southwest': {'lat': 23.8011170197085,
#                                                       'lng': 90.4215470697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': 'The Atrium Restaurant',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 2340,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/101533103536822326879">Ahmed '
#                                                 'Kamal Hasin</a>'],
#                           'photo_reference': 'Aap_uEDnXr1fhGRGCkn_ilDvfl8EOXghthhMVxrPOgrPcUGcqtu2o-0i-K9oX8Q-92JXxm5EXLc89Cwj58u6rZEa7l-mHzpvyBqxtOPXNMtnxxM_xPQpPFXn3eTs2qJDZGanW7JjvBDLckdqHYiblMXWYOUV2CAoxpLq2C4GZj4q2IPiCXbk',
#                           'width': 4160}],
#               'place_id': 'ChIJS8DMxrHHVTcRr3Fl1Xug8qY',
#               'plus_code': {'compound_code': 'RC2F+X5 Dhaka, Bangladesh',
#                             'global_code': '7MMGRC2F+X5'},
#               'price_level': 3,
#               'rating': 4,
#               'reference': 'ChIJS8DMxrHHVTcRr3Fl1Xug8qY',
#               'scope': 'GOOGLE',
#               'types': ['restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 1857,
#               'vicinity': '50 & 52, Pragati Avenue, J Block, Baridhara, Dhaka'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.7901611, 'lng': 90.4081571},
#                            'viewport': {'northeast': {'lat': 23.79150403029151,
#                                                       'lng': 90.40955878029152},
#                                         'southwest': {'lat': 23.7888060697085,
#                                                       'lng': 90.40686081970851}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': 'Street 11',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 2976,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/103569394250742175964">Setu '
#                                                 'Deay Ovi</a>'],
#                           'photo_reference': 'Aap_uEA4CDm0pvywYbxMYjD8WRL4u5HfrLLr6VPxOl9U2dvgjoJWj5XbI-s7ojaaH6TYDbdWzOFK5LNeajK5pR2__1ZeJ0463_pcXrODqcy8vtJeQmbDvJyJAMaF1nXzKHvfMnUbpNpWjTHyqSlOZuek9FDdH-wzXy92IiLiXNOtkAcBEepW',
#                           'width': 3968}],
#               'place_id': 'ChIJWxs5hgvHVTcRlYMt2iq683M',
#               'plus_code': {'compound_code': 'QCR5+37 Dhaka, Bangladesh',
#                             'global_code': '7MMGQCR5+37'},
#               'price_level': 2,
#               'rating': 3.8,
#               'reference': 'ChIJWxs5hgvHVTcRlYMt2iq683M',
#               'scope': 'GOOGLE',
#               'types': ['restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 666,
#               'vicinity': 'House 25, 3rd Floor, Block C, Road No. 11, Banani, '
#                           'Dhaka'}],
#  'status': 'OK'}

# %%
next_page_token = places_result.get('next_page_token')
#next_page_token
# Out:
# 'Aap_uED1XqUQrr9EbGWTokStBASslKQdU206sr_Ir-a4pWKEV0DDU5I52hFDEoQ_7kVi9ul2PxtsS0wWIv_4XT44wc7QbpqeypsCrQ6K1ioenWuCJOZo8eWuhahJzzrI8vJ6cUgKjeMJdKnpuOAKuP34hkl-rGjwS8gLXeVpNkHrPMMYDe6dTwoOJtQGgx8pvAzXSRY4M8Sstnesyu-U5lIAxm_zVxB22iDJPPkt6rhiNh6VSYuJj31k33nHqJoE_peOZwPxoTmQfOMGt_-3acqyo75JaPHER9ELDy95gZEBkjXmDGIrmYFgQAsx01-KnrWvw2Qn48hLkSHum3iPo08XXTWfRsaamNFY57FDf6MwDvrbq_K8dL7Ngv_Bwif0GHWLt3zPYIUi7q7TlenVBEI63z4fHoobqUQBJ_Wu-8hC1E_I-nVyLlk2RQRcTMcc'

# %%
def price_level_conversion(num):
        switch={
          0:None,
          1:'$',
          2:'$$',
          3:'$$$',
          4:'$$$$'
          }
        return switch.get(num,"Invalid input")

# %%
restraurants = []

while next_page_token:
    time.sleep(3)
    places_result = gmaps.places_nearby(location="23.684994,90.356331",
                                        radius=30000,
                                        type="restaurant",
                                        page_token=places_result['next_page_token'])
    
    for place in places_result['results']:
    
        id = place['place_id']
        fields = ['name','rating','geometry/location/lat','geometry/location/lng','user_ratings_total','price_level']
        place = gmaps.place(place_id=id,fields=fields)
        #print(place)

        try:
            name_pl = place['result']['name']
        except KeyError:
           name_pl = ""

        try:
            lat_pl = place['result']['geometry']['location']['lat']
        except KeyError:
           lat_pl = 0

        try:
            lng_pl = place['result']['geometry']['location']['lng']
        except KeyError:
           lng_pl = 0 

        try:
            rating_pl = place['result']['rating']
        except KeyError:
           rating_pl = 0

        try:
            no_review_pl = place['result']['user_ratings_total']
        except KeyError:
           no_review_pl = 0 

        try:
            price_pl = place['result']['price_level']
        except KeyError:
           price_pl = 0 

        
        restraurants.append({'Name':name_pl,
                            'Latitude':lat_pl,
                            'Longitude':lng_pl,
                            'Rating':rating_pl,
                            'Number of Reviews': no_review_pl,
                            'Affluence':price_level_conversion(price_pl)
                            })
    next_page_token = places_result.get('next_page_token')

    #print(next_page_token)

df = pd.DataFrame(restraurants)

# %%
df
# Out:
#                                              Name   Latitude  Longitude  \
# 0                                Hotel Bon Vivant  23.806904  90.416460
# 1                            Pan Tao Thai Cuisine  23.792069  90.408006
# 2                                   Haji Biriyani  23.720669  90.405779
# 3                                        amontron  23.807410  90.368412
# 4                                          Chilis  23.752052  90.377418
# 5                             Bay Leaf Restaurant  23.809889  90.367557
# 6                  Palm View Hotel and Restaurant  23.818939  90.414156
# 7             Bagicha Thai and Chinese Restaurant  23.733362  90.406535
# 8                 VIP's Restaurant & Party Center  23.802421  90.353288
# 9                        California Fried Chicken  23.737881  90.396256
# 10                       Marwa Kabab & Restaurant  23.833205  90.418238
# 11  California Fried Chicken and Pastry Shop(CFC)  23.756338  90.374756
# 12                       BFC (Best Fried Chicken)  23.741939  90.411568
# 13                       Bijoy Shoroni Restaurant  23.763102  90.389262
# 14                                  China Kitchen  23.740054  90.391265
# 15                   Zafran Biryani & Kabab house  23.783589  90.376604
# 16           Campus Shadow of University of Dhaka  23.734423  90.391979
# 17                     BG Sauslys Private Limited  23.790717  90.404391
# 18                          Red Tomato Restaurant  23.753009  90.369276
# 19                                     Pappa Roti  23.793719  90.405183
# 20         California Fried Chicken & Pastry Shop  23.798545  90.412256
# 21                                         Sayami  23.781594  90.415796
# 22                            Goonjon Bangla Cafe  23.820466  90.365228
# 23                                   Dosa Express  23.742098  90.409967
# 24                               CP Fried Chicken  23.704193  90.423978
# 25                               Shad Tehari Ghar  23.755269  90.372131
# 26                   Margarita Resturant and Cafe  23.806635  90.416221
# 27                                 Food Land Cafe  23.720230  90.417988
# 28                                  FFC Dhanmondi  23.744296  90.382376
# 29                            Sky View Restaurant  23.768046  90.403554
# 30                              Bright Star Hotel  23.759491  90.394153
# 31                     Taj Mahal Tandoori & Kabab  23.793446  90.406644
# 32                              Hotel De Meridian  23.872299  90.401001
# 33                         Salimar Garden Restora  23.792773  90.405606
# 34                                Argeela, Dhaka.  23.791056  90.406077
# 35                                    Take A Bite  23.761649  90.436338
# 36                     BG Sauslys Private Limited  23.792217  90.415171
# 37                               Royal Restaurant  23.719576  90.390543
# 38                          Piccadilly Restaurant  23.760417  90.383772
# 39                                 Cafe Appeliano  23.752009  90.421436
#
#     Rating  Number of Reviews Affluence
# 0      4.0                291      None
# 1      4.0                642      None
# 2      4.0               3983        $$
# 3      5.0                  3      None
# 4      4.1               1699        $$
# 5      3.7                950        $$
# 6      4.2               1819      None
# 7      4.0                818        $$
# 8      3.7                426        $$
# 9      3.8                398      None
# 10     3.9               1621        $$
# 11     4.1                605        $$
# 12     4.1               1858        $$
# 13     3.8                733        $$
# 14     3.9                880        $$
# 15     3.7                147         $
# 16     4.4               1045         $
# 17     3.7                 72      None
# 18     3.8                716        $$
# 19     4.3                 36      None
# 20     4.0                458        $$
# 21     3.0                 10      None
# 22     3.8                113        $$
# 23     4.1               1518        $$
# 24     3.9                143      None
# 25     4.0               1517        $$
# 26     3.3                  4      None
# 27     4.0               1066        $$
# 28     3.6                463      None
# 29     3.9                462        $$
# 30     3.8                 96         $
# 31     4.0                276      None
# 32     3.9                672      None
# 33     3.9                620        $$
# 34     3.8                231      None
# 35     3.6                885         $
# 36     4.3                170      None
# 37     4.0               4081        $$
# 38     3.6                826        $$
# 39     4.1               2635        $$

# %%
df.to_csv(r'E:\ADA\output.csv', index=False)
